# %%
import pandas as pd; 

#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)

display(vendas_DataFrame)

# %%
import pandas as pd; 

#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)
display(vendas_DataFrame.columns)

# %%
import pandas as pd; 
#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)

#Informa as colunas existentes no DataFrame
display(vendas_DataFrame.columns)

# %%
import pandas as pd; 

#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)


#Imprimir a 5 primeiras linhas do DataFrame
display(vendas_DataFrame.head())

# %%
import pandas as pd; 

#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)
#Exbir a coluna "Vendedor" do DataFrame
display(vendas_DataFrame["Vendedor"])

# %%
import pandas as pd; 

#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)


#Exbir apenas lagumas colunas do DataFrame
display(vendas_DataFrame[["Vendedor","Total Vendas"]].head())

# %%
import pandas as pd; 
#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)
#Loc limite a quantidade de linhas
display(vendas_DataFrame.loc[1:10])

# %%
import pandas as pd; 
#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)

vendas_Leonardo_Almeida_DF = vendas_DataFrame.loc[vendas_DataFrame["Vendedor"] == "Leonardo Almeida"]

#Loc limite a quantidade de vendas por vendedor
display(vendas_Leonardo_Almeida_DF)

# %%
import pandas as pd; 
#caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoLinux)

vendas_Leonardo_Almeida_DF = vendas_DataFrame.loc[vendas_DataFrame["Vendedor"] == "Leonardo Almeida",["Vendedor","Total Vendas"]]

#Loc limite a quantidade de vendas por vendedor
display(vendas_Leonardo_Almeida_DF)

# %%
import pandas as pd; 
caminhoWindows = "C:/Users/NSOUZA/OneDrive - Daimler Truck/04-CURSOS/23-Analise_dadosRPA/Vendas_Jan.xlsx"
#caminhoLinux = "/home/nsouza/Público/Cursos/analisedadosRPA/Vendas_Jan.xlsx"
vendas_DataFrame = pd.read_excel(caminhoWindows)



#Loc limite a quantidade de vendas por vendedor
display(vendas_DataFrame.shape)
